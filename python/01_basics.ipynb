# %% [markdown]
# Ось **розгорнутий контент для першого файлу `01_basics.ipynb`** з орієнтацією на **інформаційно-аналітичну діяльність військових штабів**:
#
# ---
#
# # 📘 `01_basics.ipynb`
#
# ## **Тема: Основи Python у військовій аналітиці**
#
# ---
#
# ### 🔹 Вступ
#
# Мета заняття — ознайомитися з базовими конструкціями Python, які стануть фундаментом для подальшої обробки бойових звітів, статистики втрат, даних розвідки та інших джерел інформації.
#
# ---
#
# ### 🔸 1. Змінні та типи даних
#
# #### ▶️ Основні типи:
#
# * `int` — цілі числа (кількість втрат)
# * `float` — числа з плаваючою комою (відсотки готовності)
# * `str` — текст (назви підрозділів)
# * `bool` — логічні значення (готовність: True/False)
#
# #### ✅ Приклад:
#
# ```python
# enemy_losses = 120
# readiness = 0.85
# unit_name = "1-а механізована бригада"
# is_ready = True
# ```
#
# ---
#
# ### 🔸 2. Вивід інформації
#
# ```python
# print(f"{unit_name} має рівень готовності {readiness * 100}%")
# print("Втрати противника:", enemy_losses)
# ```
#
# ---
#
# ### 🔸 3. Арифметичні оператори
#
# * `+`, `-`, `*`, `/`, `//`, `%`, `**`
#
# #### ✅ Приклад:
#
# ```python
# planned = 250
# actual = 187
# shortfall = planned - actual
# print("Недокомплект:", shortfall)
# ```
#
# ---
#
# ### 🔸 4. Логічні оператори
#
# * `==`, `!=`, `<`, `>`, `<=`, `>=`
# * `and`, `or`, `not`
#
# #### ✅ Приклад:
#
# ```python
# if readiness > 0.9 and enemy_losses > 100:
#     print("Можна перейти до активних дій.")
# else:
#     print("Потрібна додаткова підготовка.")
# ```
#
# ---
#
# ### 🔸 5. Введення даних з клавіатури
#
# ```python
# direction = input("Введіть напрямок атаки: ")
# print(f"Обрано напрямок: {direction}")
# ```
#
# ---
#
# ### 🔸 6. Умовні конструкції `if`, `elif`, `else`
#
# #### ✅ Приклад:
#
# ```python
# if enemy_losses > 200:
#     print("Ворог зазнав значних втрат")
# elif enemy_losses > 100:
#     print("Втрати середні")
# else:
#     print("Втрати незначні")
# ```
#
# ---
#
# ### 🔸 7. Цикл `for` + `range()`
#
# ```python
# for day in range(1, 6):
#     print(f"День {day}: Аналіз втрат")
# ```
#
# ---
#
# ### 🔸 8. Цикл `while`
#
# ```python
# ready = 0.5
# while ready < 0.9:
#     print(f"Поточна готовність: {ready}")
#     ready += 0.1
# ```
#
# ---
#
# ### 📝 Практичні завдання:
#
# 1. Вивести повідомлення про рівень втрат ротивника на основі введеного числа.
# 2. Порахувати середній рівень готовності трьох підрозділів.
# 3. Створити цикл, що виводить день і номер сектора з номером розрахунку.

# %% [markdown]
# ### Завдання 1. Виведення повідомлення про рівень втрат противника на основі введеного числа.

# %%
# Запитуємо користувача ввести число, що позначає рівень втрат противника
# input() повертає текстовий рядок, тому треба перетворити його на ціле число за допомогою int()
vtraty = int(input("Введіть рівень втрат противника (число): "))

# Перевіряємо значення введеного числа і виводимо повідомлення відповідно до рівня втрат

if vtraty == 0:
    # Якщо втрат немає
    print("Втрат противника немає.")
elif vtraty < 10:
    # Якщо втрати невеликі (менше 10)
    print("Втрати противника мінімальні.")
elif vtraty < 50:
    # Якщо втрати середні (від 10 до 49)
    print("Втрати противника середні.")
elif vtraty < 100:
    # Якщо втрати великі (від 50 до 99)
    print("Втрати противника великі.")
else:
    # Якщо втрати дуже великі (100 і більше)
    print("Втрати противника катастрофічні!")
# Out:
# Втрати противника мінімальні.

# %% [markdown]
# ### Завдання 2. Прорахований середній рівень готовності трьох підрозділів.

# %%
# Запитуємо користувача ввести рівень готовності для першого підрозділу
# Функція input() повертає текст, тому перетворюємо його на число (float, щоб можна було вводити дробові числа)
ready1 = float(input("Введіть рівень готовності першого підрозділу: "))

# Запитуємо рівень готовності другого підрозділу
ready2 = float(input("Введіть рівень готовності другого підрозділу: "))

# Запитуємо рівень готовності третього підрозділу
ready3 = float(input("Введіть рівень готовності третього підрозділу: "))

# Обчислюємо середній рівень готовності
# Сумуємо три значення і ділимо на 3
average_ready = (ready1 + ready2 + ready3) / 3

# Виводимо результат на екран
print("Середній рівень готовності трьох підрозділів:", average_ready)
# Out:
# Середній рівень готовності трьох підрозділів: 71.66666666666667

# %% [markdown]
# ### Завдання 3. Створено цикл, що виводить день і номер сектора з номером розрахунку.

# %%
# Припустимо, що ми маємо 7 днів (наприклад, тиждень)
# І для кожного дня є сектор і номер розрахунку, які ми виводимо

# Кількість днів для циклу
days_count = 7

# Використовуємо цикл for для перебору днів від 1 до 7 включно
for day in range(1, days_count + 1):
    # Припустимо, що номер сектора дорівнює номеру дня (наприклад, сектор 1 для дня 1 і т.д.)
    sector_number = day
    
    # Номер розрахунку можна задати як довільне число, наприклад, day * 10 (або будь-яка логіка)
    calculation_number = day * 10
    
    # Виводимо інформацію у зручному форматі
    print(f"День {day}: сектор {sector_number}, номер розрахунку {calculation_number}")
# Out:
# День 1: сектор 1, номер розрахунку 10
# День 2: сектор 2, номер розрахунку 20
# День 3: сектор 3, номер розрахунку 30
# День 4: сектор 4, номер розрахунку 40
# День 5: сектор 5, номер розрахунку 50
# День 6: сектор 6, номер розрахунку 60
# День 7: сектор 7, номер розрахунку 70
